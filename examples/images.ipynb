# %% [markdown]
# # Image Examples

# %%
from openai import OpenAI

# Configure client to use local server
client = OpenAI(
    base_url="http://localhost:8000/v1",  # Point to local server
    api_key="not-needed"  # API key is not required for local server
)

# %%
from IPython.display import display, Image as IPyImage
import io

def display_image(image):
    img_byte_arr = io.BytesIO()
    image.save(img_byte_arr, format='PNG')
    img_byte_arr = img_byte_arr.getvalue()
    display(IPyImage(data=img_byte_arr))

# %% [markdown]
# ## v1/images/generations

# %% [markdown]
# You can directly test using the curl method, as follows:
#
# ```shell
# curl http://localhost:8000/v1/images/generations \
#   -H "Content-Type: application/json" \
#   -d '{
#     "model": "argmaxinc/mlx-FLUX.1-schnell",
#     "prompt": "A cute baby sea otter",
#     "n": 1,
#     "size": "1024x1024"
#   }'
#
# ```
#
# You can also use OpenAI's Python SDK in the project for access, which can basically be done without feeling. As follows:

# %%
response = client.images.generate(
    model="argmaxinc/mlx-FLUX.1-schnell",
    prompt="A beautiful sunset over mountains",
    n=1,
    size="512x512",
    response_format="url"
)

response
# Out:
# ImagesResponse(created=1731569329, data=[Image(b64_json=None, revised_prompt='A beautiful sunset over mountains', url='file:///var/folders/zd/866zf6nx4h3__dptsp9fkjt00000gq/T/mlx_omni_server/images/1731569160_0.png')])

# %%
display_image(response.data[0].url)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 display_image(response.data[0].url)
#
# Cell In[11], line 8, in display_image(image)
#       6 # 将PIL图像转换为字节流
#       7 img_byte_arr = io.BytesIO()
# ----> 8 image.save(img_byte_arr, format='PNG')
#       9 img_byte_arr = img_byte_arr.getvalue()
#      11 # 使用IPython的display显示图像
#
# AttributeError: 'str' object has no attribute 'save'

# %%
response = client.images.generate(
    model="argmaxinc/mlx-FLUX.1-schnell",
    prompt="A beautiful sunset over mountains",
    n=1,
    size="512x512",
    extra_body={
        "negative_prompt": "ugly, blurry",
    }
)

response
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 response = client.images.generate(
#       2     model="argmaxinc/mlx-FLUX.1-schnell",
#       3     prompt="A beautiful sunset over mountains",
#       4     n=1,
#       5     size="512x512",
#       6     extra_body={
#       7         "negative_prompt": "ugly, blurry",  # 会被传递给generate_image
#       8         "denoise": 0.8,                     # 会被传递给generate_image
#       9         "use_t5": True                      # 会被传递给generate_image
#      10     }
#      11 )
#      13 response
#
# File /opt/homebrew/lib/python3.11/site-packages/openai/resources/images.py:264, in Images.generate(self, prompt, model, n, quality, response_format, size, style, user, extra_headers, extra_query, extra_body, timeout)
#     205 def generate(
#     206     self,
#     207     *,
#    (...)
#     221     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     222 ) -> ImagesResponse:
#     223     """
#     224     Creates an image given a prompt.
#     225
#    (...)
#     262       timeout: Override the client-level default timeout for this request, in seconds
#     263     """
# --> 264     return self._post(
#     265         "/images/generations",
#     266         body=maybe_transform(
#     267             {
#     268                 "prompt": prompt,
#     269                 "model": model,
#     270                 "n": n,
#     271                 "quality": quality,
#     272                 "response_format": response_format,
#     273                 "size": size,
#     274                 "style": style,
#     275                 "user": user,
#     276             },
#     277             image_generate_params.ImageGenerateParams,
#     278         ),
#     279         options=make_request_options(
#     280             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     281         ),
#     282         cast_to=ImagesResponse,
#     283     )
#
# File /opt/homebrew/lib/python3.11/site-packages/openai/_base_client.py:1277, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1263 def post(
#    1264     self,
#    1265     path: str,
#    (...)
#    1272     stream_cls: type[_StreamT] | None = None,
#    1273 ) -> ResponseT | _StreamT:
#    1274     opts = FinalRequestOptions.construct(
#    1275         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1276     )
# -> 1277     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/homebrew/lib/python3.11/site-packages/openai/_base_client.py:954, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     951 else:
#     952     retries_taken = 0
# --> 954 return self._request(
#     955     cast_to=cast_to,
#     956     options=options,
#     957     stream=stream,
#     958     stream_cls=stream_cls,
#     959     retries_taken=retries_taken,
#     960 )
#
# File /opt/homebrew/lib/python3.11/site-packages/openai/_base_client.py:1043, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1041 if remaining_retries > 0 and self._should_retry(err.response):
#    1042     err.response.close()
# -> 1043     return self._retry_request(
#    1044         input_options,
#    1045         cast_to,
#    1046         retries_taken=retries_taken,
#    1047         response_headers=err.response.headers,
#    1048         stream=stream,
#    1049         stream_cls=stream_cls,
#    1050     )
#    1052 # If the response is streamed then we need to explicitly read the response
#    1053 # to completion before attempting to access the response text.
#    1054 if not err.response.is_closed:
#
# File /opt/homebrew/lib/python3.11/site-packages/openai/_base_client.py:1092, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1088 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1089 # different thread if necessary.
#    1090 time.sleep(timeout)
# -> 1092 return self._request(
#    1093     options=options,
#    1094     cast_to=cast_to,
#    1095     retries_taken=retries_taken + 1,
#    1096     stream=stream,
#    1097     stream_cls=stream_cls,
#    1098 )
#
# File /opt/homebrew/lib/python3.11/site-packages/openai/_base_client.py:1043, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1041 if remaining_retries > 0 and self._should_retry(err.response):
#    1042     err.response.close()
# -> 1043     return self._retry_request(
#    1044         input_options,
#    1045         cast_to,
#    1046         retries_taken=retries_taken,
#    1047         response_headers=err.response.headers,
#    1048         stream=stream,
#    1049         stream_cls=stream_cls,
#    1050     )
#    1052 # If the response is streamed then we need to explicitly read the response
#    1053 # to completion before attempting to access the response text.
#    1054 if not err.response.is_closed:
#
# File /opt/homebrew/lib/python3.11/site-packages/openai/_base_client.py:1092, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1088 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1089 # different thread if necessary.
#    1090 time.sleep(timeout)
# -> 1092 return self._request(
#    1093     options=options,
#    1094     cast_to=cast_to,
#    1095     retries_taken=retries_taken + 1,
#    1096     stream=stream,
#    1097     stream_cls=stream_cls,
#    1098 )
#
# File /opt/homebrew/lib/python3.11/site-packages/openai/_base_client.py:1058, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1055         err.response.read()
#    1057     log.debug("Re-raising status error")
# -> 1058     raise self._make_status_error_from_response(err.response) from None
#    1060 return self._process_response(
#    1061     cast_to=cast_to,
#    1062     options=options,
#    (...)
#    1066     retries_taken=retries_taken,
#    1067 )
#
# InternalServerError: Error code: 500 - {'detail': "Error generating image: DiffusionPipeline.generate_image() got an unexpected keyword argument 'prompt'"}
